# %%
# %pip install pandas numpy matplotlib seaborn dask[dataframe]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 118.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 117.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 152.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.1/285.1 kB 93.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 124.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.8/500.8 kB 112.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 131.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.8/960.8 kB 147.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 157.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.9/295.9 kB 87.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 19.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
from pathlib import Path
folder = Path('data/raw/')
files = list(folder.glob('**/SPEC*'))
files
# Out:
# [PosixPath('data/raw/Spectra/SPEC20210212_01'),
#  PosixPath('data/raw/Spectra/SPEC20210212_02'),
#  PosixPath('data/raw/Spectra/SPEC20210212_03'),
#  PosixPath('data/raw/Spectra/SPEC20210212_04'),
#  PosixPath('data/raw/Spectra/SPEC20210212_05'),
#  PosixPath('data/raw/Spectra/SPEC20210212_06'),
#  PosixPath('data/raw/Spectra/SPEC20210212_07')]

# %%
all_dfs = {}
for filename in files:
    all_dfs[str(filename.stem)] = pd.read_csv(filename, sep='\t', header=None)
all_dfs['SPEC20210212_03'].head()
# Out:
#             0          1       2         3         4         5         6   \
# 0  215371351.0  96.044997  7.9970  0.000246  0.000009 -0.000167  0.000081
# 1  215371758.0  96.044997  8.0514  0.000269  0.000005 -0.000166  0.000081
# 2  215372110.0  96.044997  8.1003  0.000274  0.000006 -0.000165  0.000081
# 3  215372429.0  96.044997  8.1509  0.000276  0.000005 -0.000165  0.000080
# 4  215372758.0  96.044997  8.2003  0.000277  0.000004 -0.000164  0.000080
#
#          7      8         9   ...        12          13        14        15  \
# 0  0.002076  300.0  0.002286  ...  0.000444  881.822906 -0.000077 -0.000169
# 1  0.002149  300.0  0.002290  ...  0.000445  887.066082 -0.000077 -0.000168
# 2  0.002230  300.0  0.002289  ...  0.000446  891.777268 -0.000077 -0.000167
# 3  0.002309  300.0  0.002290  ...  0.000444  896.650355 -0.000076 -0.000166
# 4  0.002388  300.0  0.002287  ...  0.000445  901.406026 -0.000076 -0.000166
#
# ...
